# %% [markdown]
# # WER - Open Mini-Challenge

# %% [markdown]
# ## Fragestellung:
# ### Was ist der Anteil Elektroautos im Verkauf in der Schweiz in 2030?

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# ### Anteil EV Auto
# Wir haben die Daten von 2018 - 2021 herausgesucht und daraus einen Trend aufgestellt bis 2030. Laut Trend wird der Anteil E-Autos in 2030 bei 44.20% liegen. Das Ergebnis wird sich noch durch Zufallsvariablen, die wir weiter unten definiert haben, ändern.

# %%
df_anteil = pd.read_csv("Anteil_E_Autos.csv")
df_anteil.plot(x="Jahr", y="Anteil")
plt.show()

# %% [markdown]
# ### Zufallsvariable: Reichweite
# Wir haben die 10 Elektroautos mit der grössten Reichweite der letzten 4 Jahre rausgesucht und dazu ein Diagramm aufgestellt.

# %%
# Top 10 Reichweiten pro Jahr
df_reichw = pd.read_csv("Reichweiten.csv")
df_reichw.plot(x="Rang", y=["2018", "2019", "2020", "2021"])
plt.show()

# %% [markdown]
# Anhand dieses Diagrammes sieht man, dass die Top 10 E-Autos nach Reichweite immer steigen. Das 10. Auto war in 2018 bei ungefähr 270km und in 2021 bei 536km.

# %% [markdown]
# Durchschnitte der 10 Autos:
#
#
#
# Streudiagramm:

# %%
# Mittelwert und STAB der Top 10 Elektroautos nach Reichweite
mit_reichw = []
mit_reichw.append(np.mean(df_reichw["2018"]))
mit_reichw.append(np.mean(df_reichw["2019"]))
mit_reichw.append(np.mean(df_reichw["2020"]))
mit_reichw.append(np.mean(df_reichw["2021"]))

# In Excel ausgerechnete Mittelwerte für unbekannte Jahren 2022 - 2030 (TREND)
mit_reichw.extend((653.0, 712.7, 772.4, 832.1, 891.8, 951.5, 1011.2, 1070.9, 1130.6))

jahren = [2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026, 2027, 2028, 2029, 2030]

plt.plot(jahren, mit_reichw)

# %%
# Durchschnitt STAB
reichw_stab_lst = []
reichw_stab_lst.append(np.std(df_reichw["2018"]))
reichw_stab_lst.append(np.std(df_reichw["2019"]))
reichw_stab_lst.append(np.std(df_reichw["2020"]))
reichw_stab_lst.append(np.std(df_reichw["2021"]))

reichw_stab = np.std(reichw_stab_lst)

# %% [markdown]
# #### Wahrscheinlichkeitsverteilung 2021
# Reichweite: Stetig, > 0

# %%
def plot_distr(dataframe, x_val):
    sns.set_style('white')
    sns.set_context("paper", font_scale = 1.5)
    sns.displot(data = dataframe, x = x_val, kind = "hist", bins = 150, aspect = 3.0)

# %%
sim_reichweite = np.random.normal(mit_reichw[3], reichw_stab_lst[3], 100_000)
df_sim_reichweite = pd.DataFrame(sim_reichweite)
plot_distr(df_sim_reichweite, sim_reichweite)

# %% [markdown]
# #### Wahrscheinlichkeitsverteilung 2030

# %%
sim_reichweite = np.random.normal(mit_reichw[-1], reichw_stab, 100_000)
df_sim_reichweite = pd.DataFrame(sim_reichweite)
plot_distr(df_sim_reichweite, sim_reichweite)

# %% [markdown]
# ### Zufallsvariable: Batteriekosten (Lithium)

# %% [markdown]
# Vor zehn Jahren galt ein Elektroauto noch als unbezahlbar. 1100 Dollar kostete die Kilowattstunde (kWh) einer Lithium-Ionen-Batterie damals. Seitdem sind die Preise in einem rasanten Tempo gefallen: um mehr als 89 Prozent auf 137 Dollar pro kWh 2020.
#
# - Akkupreis seit Anfang Jahrzehnt um 87% gesunken
# - wird noch bis 2025 halbieren
#
# Verteilung: Exponential

# %% [markdown]
# ### Zufallsvariable: Antriebskosten

# %% [markdown]
# Wir gehen davon aus, dass die E-Autos zuhause geladen werden. Dieser Preis liegt heutzutage bei 0.24.- pro KWH

# %%
df_antriebkosten = pd.read_csv("Antriebkosten.csv")
df_antriebkosten.plot(x="Jahr", y=["Bleifrei(95)", "Bleifrei(98)", "Diesel", "KWH"])
plt.show()

# %% [markdown]
# Trend - Antriebkosten (2010 - 2030)

# %%
df_antriebkosten_trend = pd.read_csv("Antriebkosten_Trend.csv")
df_antriebkosten_trend.plot(x="Jahr", y=["Bleifrei(95)", "Bleifrei(98)", "Diesel", "KWH"])
plt.show()

# %% [markdown]
# #### Wahrscheinlichkeitsverteilung 2021 Bleifrei(95)

# %%
stab_bleifrei_95 = np.std(df_antriebkosten_trend["Bleifrei(95)"])
sim_bleifrei_95 = np.random.normal(df_antriebkosten_trend["Bleifrei(95)"][11], stab_bleifrei_95, 100_000)
df_sim_bleifrei_95 = pd.DataFrame(sim_bleifrei_95)
plot_distr(df_sim_bleifrei_95, sim_bleifrei_95)

# %% [markdown]
# #### Wahrscheinlichkeitsverteilung Bleifrei(98) 2021

# %%
stab_bleifrei_98 = np.std(df_antriebkosten_trend["Bleifrei(98)"])
sim_bleifrei_98 = np.random.normal(df_antriebkosten_trend["Bleifrei(98)"][11], stab_bleifrei_98, 100_000)
df_sim_bleifrei_98 = pd.DataFrame(sim_bleifrei_98)
plot_distr(df_sim_bleifrei_98, sim_bleifrei_98)

# %% [markdown]
# #### Wahrscheinlichkeitsverteilung Diesel 2021

# %%
stab_diesel = np.std(df_antriebkosten_trend["Diesel"])
sim_diesel = np.random.normal(df_antriebkosten_trend["Diesel"][11], stab_diesel, 100_000)
df_sim_diesel = pd.DataFrame(sim_diesel)
plot_distr(df_sim_diesel, sim_diesel)

# %% [markdown]
# #### Wahrscheinlichkeitsverteilung KWH 2021

# %%
stab_kwh = np.std(df_antriebkosten_trend["KWH"])
sim_kwh = np.random.normal(df_antriebkosten_trend["KWH"][11], stab_kwh, 100_000)
df_sim_kwh = pd.DataFrame(sim_kwh)
plot_distr(df_sim_kwh, sim_kwh)

# %% [markdown]
# ### Zufallsvariable: Preis EV relativ zu Benzin / Diesel
# Für diesen vergleich haben wir 8 identische Autos genommen, die es als EV und Benzin / Diesel gibt.

# %%
# Top 10 Reichweiten pro Jahr
df_preise = pd.read_csv("Autopreise_e_vs_b.csv")
df_preise.plot(x="Auto", y=["EV Preis", "BD Preis"])
plt.show()

# %%
mit_ev = np.mean(df_preise["EV Preis"])
mit_bd = np.mean(df_preise["BD Preis"])

df_preise
# Out:
#               Auto  EV Preis  BD Preis
# 0           BMW i4     69900     56400
# 1      Mini Cooper     37900     26000
# 2       Opel Corsa     35000     19000
# 3   Opel Grandland     44260     32450
# 4       Opel Mokka     36200     26200
# 5  Opel Combo Life     40800     26460
# 6      Peugeot 208     33000     18500
# 7       Volvo xc40     59500     36840

# %% [markdown]
# prozent anzahl

# %% [markdown]
# ### Delta Kaufpreis (Händler)

# %% [markdown]
# ### Delta Kilometerpreis

# %% [markdown]
# Verifox: Durchschnittlicher Verbrauch pro 100km im Jahr 2020 liegt bei 15KWH
#
# Statista: Durchschnittlicher Verbrauch pro 100km im Jahr 2020 liegt bei 5.7 Liter

# %%
verbrauch_kwh = 15
kosten_kwh = df_antriebkosten["KWH"][10]
preis_kwh = verbrauch_kwh * kosten_kwh

verbrauch_bleifrei = 5.7
kosten_bleifrei = df_antriebkosten["Bleifrei(95)"][10]
preis_bleifrei = verbrauch_bleifrei * kosten_bleifrei

print("Preis pro KWH:   CHF {}\nPreis pro Liter: CHF {}".format(preis_kwh, preis_bleifrei))

delta_km_preis = (preis_bleifrei - preis_kwh) / 100

print(delta_km_preis)
# Out:
# Preis pro KWH:   CHF 3.657
# Preis pro Liter: CHF 8.151
# 0.04494

# %% [markdown]
# ### Subventionen

# %% [markdown]
# ### Kaufbereitschaft
# In diesem Abschnitt definieren wir, wann die Kaufbereitschaft der Kunden für ein EV Fahrzeug steigen könnte.
#
#
# - Reichweite wird immer grösser
# - Benzin / Diesel wird immer teurer
#     - Steuern auf Benzin
#     - Kilometerpreis
# - Kaufpreis wird immer billiger
# - Subventionen auf Kauf
